# %%
import pandas as pd

# %%
datos = pd.read_csv(filepath_or_buffer='files/datos_ws.csv')
datos
# Out:
#            Nombre                               Correo
# 0           Julio                 jespinozal@armada.cl
# 1      Cristofher    cristofher.ambiado@valoralabs.com
# 2            Luis                   lpizarro@gassur.cl
# 3          Camila                 cammaldonado@udec.cl
# 4          Milton                  micartesr@gmail.com
# 5         Rodrigo            rmardones@buseshualpen.cl
# 6       Alejandra          a.varela.vallejos@gmail.com
# 7           Marco       marco.morales.espejo@gmail.com
# 8           Carla      carla.araneda@biomedica.udec.cl
# 9        Cristián                chilotronic@gmail.com
# 10        Roberto             rmella@muellesdepenco.cl
# 11         Andrés                   aabrigob@gmail.com
# 12        Sylvia                    syfuente@gmail.com
# 13         Javier            javier.cabeza07@gmail.com
# 14  Cristian Toro                    krltoro@gmail.com
# 15      Sebastián            seortiz@enaprefinerias.cl
# ...

# %%
cols = datos.columns

# %%
'Nombres' in cols
# Out:
# False

# %%
display(datos)
# Out:
#   Nombre       Empresa                 Correo   Sexo
# 0   Aldo           UDS      aldconcha@udec.cl   True
# 1   Alda  Monster Inc.  aldoconchao@gmail.com  False

# %%
def dis(path, **k):
    df = pd.read_csv(path, **k)
    display(df)

# %%
dis('files/datos.csv', sep=',', hola='chao')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-d5cfb4a76f4c> in <module>
# ----> 1 dis('files/datos.csv', sep=',', hola='chao')
#
# <ipython-input-4-1f0bf0bc9944> in dis(path, **k)
#       1 def dis(path, **k):
# ----> 2     df = pd.read_csv(path, **k)
#       3     display(df)
#       4
#
# TypeError: parser_f() got an unexpected keyword argument 'hola'

# %%
'hola'.replace({'a': 'o'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-00ecea384ef8> in <module>
# ----> 1 'hola'.replace({'a': 'o'})
#
# TypeError: replace() takes at least 2 arguments (1 given)

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer:Union[str, pathlib.Path, IO[~AnyStr]], sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal:str='.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
# ...
